# %% [markdown]
# <h1> Mixture Density Network </h1>
#
# This notebook is essentially a reproduction of the "Simple Inverse Problem" presented in
# <a href="http://publications.aston.ac.uk/373/1/NCRG_94_004.pdf">Mixture Density Networks (Bishop, 1994)</a>
#
# It shows the weakness a standard neural net has in predicting target data that has more than one mode. It motivates training the net to output a mixture model instead of a single conditioned average of the distribution.
#
# <h2> Two data sets that are really the same data:</h2>

# %%
datafunction(x) = x + 0.3*sin(2*π*x) + rand()*0.2-0.1
x = zeros(1,1001)
x .= collect(0:0.001:1)'
t = datafunction.(x)

using Plots; gr(size=(800,400), leg=false)
p1=scatter(x',t', title="easy")
p2=scatter(t',x', title="hard")
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 38.8117,375.813 380.315,375.813 380.315,31.4961 38.8117,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="38" y="31" width="343" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.4769,370.649 48.4769,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   129.02,370.649 129.02,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   209.563,370.649 209.563,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   290.107,370.649 290.107,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   370.65,370.649 370.65,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.9343,342.827 375.192,342.827
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.9343,272.748 375.192,272.748
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.9343,202.67 375.192,202.67
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.9343,132.591 375.192,132.591
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.9343,62.5117 375.192,62.5117
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 380.315,375.813
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.4769,375.813 48.4769,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   129.02,375.813 129.02,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   209.563,375.813 209.563,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   290.107,375.813 290.107,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   370.65,375.813 370.65,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,375.813 38.8117,31.4961
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,342.827 43.9343,342.827
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,272.748 43.9343,272.748
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,202.67 43.9343,202.67
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,132.591 43.9343,132.591
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,62.5117 43.9343,62.5117
#   "/>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.4769, 390.613)" x="48.4769" y="390.613">0.00</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 129.02, 390.613)" x="129.02" y="390.613">0.25</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 209.563, 390.613)" x="209.563" y="390.613">0.50</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 290.107, 390.613)" x="290.107" y="390.613">0.75</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 370.65, 390.613)" x="370.65" y="390.613">1.00</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.8117, 347.327)" x="30.8117" y="347.327">0.00</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.8117, 277.248)" x="30.8117" y="277.248">0.25</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.8117, 207.17)" x="30.8117" y="207.17">0.50</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.8117, 137.091)" x="30.8117" y="137.091">0.75</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 30.8117, 67.0117)" x="30.8117" y="67.0117">1.00</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 209.563, 18)" x="209.563" y="18">easy</text>
# </g>
# <circle clip-path="url(#clip1802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="48.4769" cy="359.342" r="4"/>
# <circle clip-path="url(#clip1802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="48.4769" cy="359.342" r="3"/>
# <circle clip-path="url(#clip1802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="48.7991" cy="359.549" r="4"/>
# <circle clip-path="url(#clip1802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="48.7991" cy="359.549" r="3"/>
# <circle clip-path="url(#clip1802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="49.1213" cy="339.04" r="4"/>
# <circle clip-path="url(#clip1802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="49.1213" cy="339.04" r="3"/>
# <circle clip-path="url(#clip1802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="49.4434" cy="366.069" r="4"/>
# <circle clip-path="url(#clip1802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="49.4434" cy="366.069" r="3"/>
# <circle clip-path="url(#clip1802)" style="fill:#000000; stroke:none; fill-opacity:1" cx="49.7656" cy="330.929" r="4"/>
# <circle clip-path="url(#clip1802)" style="fill:#009af9; stroke:none; fill-opacity:1" cx="4

# %% [markdown]
# <h2> Functions for implementing a Standard Neural Net and a Mixture Density Net</h2>

# %%
function fprop!(x, W,b,z,y)
    A_mul_B!(z[1], W[1], x); z[1].+=b[1]
    @. y[1] = tanh(z[1])
    A_mul_B!(z[2], W[2], y[1]); z[2].+=b[2]
    @. y[2] = 1*z[2]
end

function ∇MSE!(∇z, y,t)
    @. ∇z[2] = y[2]-t
end

function bprop!(∇W,∇z,∇y, W,x,y)
    A_mul_Bt!(∇W[2], ∇z[2], y[1])
    At_mul_B!(∇y[1], W[2], ∇z[2])    
    @. ∇z[1] = ∇y[1] * (1-y[1]^2)
    A_mul_Bt!(∇W[1], ∇z[1], x)
end

function adjust!(W,b, ∇W,∇z, α)
    for n=1:length(b)
        @. W[n] -= α*∇W[n]
        b[n] .-= α*sum(∇z[n],2)
    end
end

function preallocate(Lw, bsz)
    N = length(Lw)-1
        
    W = [randn(Lw[n+1],Lw[n])./sqrt(Lw[n]) for n=1:N]
    ∇W = deepcopy(W)
    b = [zeros(Lw[n+1],1) for n=1:N]
    ∇b = deepcopy(b)
    
    z = [zeros(Lw[n+1],bsz) for n=1:N]
    ∇z = deepcopy(z)
    y = [zeros(Lw[n+1],bsz) for n=1:N]
    ∇y = deepcopy(y)
    return W,b,z,y, ∇W,∇b,∇z,∇y
end

function softmax(x)
    m=maximum(x,1)
    p = exp.(x .- m)
    return p ./ sum(p,1)
end

function Φ(t,μ,σ,c)
    return 1/(σ*(2*π)^(c/2)) * exp(-norm(t-μ)^2/(2*σ^2))
end

function ∇MD(z,t, m,c)
    μ = z[1:m,:]
    σ = exp.(z[m+1:2*m,:])
    α = softmax(z[2*m+1:3*m,:])
    #p = α.*hcat([Φ.(t[:]',μ[i,:],σ[i,:], c) for i=1:m]...)'
    p = α.*hcat([Φ.(t[1,:],μ[i,:],σ[i,:], c) for i=1:m]...)'
    pp = p./sum(p,1) #posterior probability (π)
    
    #get bprop started
    ∇zμ = pp.*hcat([(μ[i,:].-t[1,:])./σ[i,:].^2 for i=1:m]...)'
    ∇zσ = -pp.*hcat([(t[1,:].-μ[i,:]).^2 ./ σ[i,:].^2 - c for i=1:m]...)'
    ∇zα = α.-pp
    return vcat(∇zμ,∇zσ,∇zα)
end
# Out:
# ∇MD (generic function with 1 method)

# %% [markdown]
# <h2> Standard Neural Net</h2>

# %%
#normal feed forward net
function trainFFN(x, t, Lw, bsz, Mepoch, α)
    W,b,z,y, ∇W,∇b,∇z,∇y = preallocate(Lw,bsz)
    for epoch=1:Mepoch
        idx=randperm(size(x,2))
        for n=1:bsz:size(x,2)-bsz
            bidx=idx[n:n+bsz-1]
            xb=x[bidx]'
            fprop!(xb, W,b,z,y)
            ∇MSE!(∇z, y,t[bidx]')
            bprop!(∇W,∇z,∇y, W,xb,y)
            adjust!(W,b, ∇W,∇z, α)
        end
    end
    return W, b
end
# Out:
# trainFFN (generic function with 1 method)

# %% [markdown]
# <h2> Mixture Density Net</h2>

# %%
#mixture density net
function trainMDN(x, t, Lw, m,c, bsz, Mepoch, α)
    W,b,z,y, ∇W,∇b,∇z,∇y = preallocate(Lw,bsz)
    for epoch=1:Mepoch
        idx=randperm(size(x,2))
        for n=1:bsz:size(x,2)-bsz
            bidx=idx[n:n+bsz-1]
            xb=x[bidx]'
            fprop!(xb, W,b,z,y)
            ∇z[2] = ∇MD(z[2], t[bidx]', m,c)
            bprop!(∇W,∇z,∇y, W,xb,y)
            adjust!(W,b, ∇W,∇z, α)
        end
    end
    return W, b
end
# Out:
# trainMDN (generic function with 1 method)

# %% [markdown]
# <h2> Train standard net</h2>

# %%
c=1 #dimensionality of output
bsz=32
x_eval=collect(0:0.01:1)'

W_e, b_e = trainFFN(x,t, [1,20,c], bsz, 10000, 1e-2) #train a FFN on the easy mapping x -> t
predictions_easy = W_e[2]*(tanh.(W_e[1]*x_eval.+b_e[1])).+b_e[2]

W_h, b_h = trainFFN(t,x, [1,20,c], bsz,100000, 1e-2) #train a FFN on the hard mapping t -> x
predictions_hard = W_h[2]*(tanh.(W_h[1]*x_eval.+b_h[1])).+b_h[2];

# %% [markdown]
# <h2> This is what it learns</h2>
# Its models the x->t mapping easily, but struggles with the t->x mapping
#
# The red dots are what the net predicts, given a certain input

# %%
p1=scatter(x',t', title="easy")
scatter!(p1, x_eval', predictions_easy', ylim=(0,1), xlim=(0,1))
p2=scatter(t',x', title="hard")
scatter!(p2, x_eval', predictions_hard', ylim=(0,1), xlim=(0,1))
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2000)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2000)" points="
# 32.2221,377.923 380.315,377.923 380.315,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="31" width="349" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,372.727 32.2221,36.6925
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.841,372.727 101.841,36.6925
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.459,372.727 171.459,36.6925
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.078,372.727 241.078,36.6925
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   310.696,372.727 310.696,36.6925
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   380.315,372.727 380.315,36.6925
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,377.923 375.094,377.923
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,308.638 375.094,308.638
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,239.352 375.094,239.352
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,170.067 375.094,170.067
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,100.781 375.094,100.781
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,31.4961 375.094,31.4961
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 380.315,377.923
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,372.727
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.841,377.923 101.841,372.727
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.459,377.923 171.459,372.727
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.078,377.923 241.078,372.727
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   310.696,377.923 310.696,372.727
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   380.315,377.923 380.315,372.727
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 37.4435,377.923
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,308.638 37.4435,308.638
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,239.352 37.4435,239.352
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,170.067 37.4435,170.067
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,100.781 37.4435,100.781
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,31.4961 37.4435,31.4961
#   "/>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 392.723)" x="32.2221" y="392.723">0.0</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.841, 392.723)" x="101.841" y="392.723">0.2</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.459, 392.723)" x="171.459" y="392.723">0.4</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 241.078, 392.723)" x="241.078" y="392.723">0.6</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 310.696, 392.723)" x="310.696" y="392.723">0.8</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 380.315, 392.723)" x="380.315" y="392.723">1.0</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 382.423)" x="24.2221" y="382.423">0.0</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 313.138)" x="24.2221" y="313.138">0.2</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 243.852)" x="24.2221" y="243.852">0.4</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 174.567)" x="24.2221" y="174.567">0.6</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 105.281)" x="24.2221" y="105.281">0.8</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 35.9961)" x="24.2221" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 206.269, 18)" x="206.269" y="18">easy</text>
# </g>
# <circle clip-path="url(#clip2002)" sty

# %%
function preds2params(preds, m)
    μ = preds[1:m,:]
    σ = exp.(preds[m+1:2*m,:])
    α = softmax(preds[2*m+1:3*m,:])
    mp = findmax(α,1)[2]
    return μ,σ,α,mp
end
# Out:
# preds2params (generic function with 1 method)

# %% [markdown]
# <h2> Train Mixture Density Net</h2>

# %%
m=1 #nr of kernels
W_e, b_e = trainMDN(x,t, [1,20,(c+2)*m], m,c,bsz, 10000, 1e-5)  #train a MDN on the easy mapping x -> t
predictions_easy = W_e[2]*(tanh.(W_e[1]*x_eval.+b_e[1])).+b_e[2]
μ_e, σ_e, α_e, mp_e = preds2params(predictions_easy, m)

m=3  #nr of kernels
W_h, b_h = trainMDN(t,x, [1,20,(c+2)*m], m,c,bsz,100000, 1e-5)  #train a MDN on the hard mapping t -> x
predictions_hard = W_h[2]*(tanh.(W_h[1]*x_eval.+b_h[1])).+b_h[2]
μ_h, σ_h, α_h, mp_h = preds2params(predictions_hard, m);

# %% [markdown]
# <h2> This is what it learns</h2>
# It also models the x->t mapping easily. And does a better job with the t->x mapping
#
# The red dots are what the net predicts, given a certain input

# %%
p1 = scatter(x',t', title="easy")
scatter!(p1, x_eval', μ_e[mp_e]', ylim=(0,1), xlim=(0,1))
p2=scatter(t',x', title="hard")
scatter!(p2, x_eval', μ_h[mp_h]', ylim=(0,1), xlim=(0,1))
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 32.2221,377.923 380.315,377.923 380.315,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="31" width="349" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,372.727 32.2221,36.6925
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.841,372.727 101.841,36.6925
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.459,372.727 171.459,36.6925
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.078,372.727 241.078,36.6925
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   310.696,372.727 310.696,36.6925
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   380.315,372.727 380.315,36.6925
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,377.923 375.094,377.923
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,308.638 375.094,308.638
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,239.352 375.094,239.352
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,170.067 375.094,170.067
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,100.781 375.094,100.781
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,31.4961 375.094,31.4961
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 380.315,377.923
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,372.727
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.841,377.923 101.841,372.727
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.459,377.923 171.459,372.727
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.078,377.923 241.078,372.727
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   310.696,377.923 310.696,372.727
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   380.315,377.923 380.315,372.727
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 37.4435,377.923
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,308.638 37.4435,308.638
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,239.352 37.4435,239.352
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,170.067 37.4435,170.067
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,100.781 37.4435,100.781
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,31.4961 37.4435,31.4961
#   "/>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 392.723)" x="32.2221" y="392.723">0.0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.841, 392.723)" x="101.841" y="392.723">0.2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.459, 392.723)" x="171.459" y="392.723">0.4</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 241.078, 392.723)" x="241.078" y="392.723">0.6</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 310.696, 392.723)" x="310.696" y="392.723">0.8</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 380.315, 392.723)" x="380.315" y="392.723">1.0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 382.423)" x="24.2221" y="382.423">0.0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 313.138)" x="24.2221" y="313.138">0.2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 243.852)" x="24.2221" y="243.852">0.4</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 174.567)" x="24.2221" y="174.567">0.6</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 105.281)" x="24.2221" y="105.281">0.8</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 35.9961)" x="24.2221" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 206.269, 18)" x="206.269" y="18">easy</text>
# </g>
# <circle clip-path="url(#clip2202)" sty

# %% [markdown]
# <h2> Not only that</h2>
# We get means, variances and amplitudes of the mixture components. A heatmap visualizes more clearly what the mixture density net has learned. The plot above only shows the mean of the most probable kernel, but they all contribute to the posterior probabilities.
#
# With an input value of 0.5 the trained Mixture Density Net will say that the output is
# <li>about 0.2 with 25% probability,
# <li>about 0.5 with 50% probability,
# <li>about 0.8 with 25% probability.
#
# This is something a standard neural net cannot do.
#
# See figure below, the strength of color corresponds to probability that the output (given an input) should lie in certain regions.

# %%
gr(size=(800,400))
hm_easy = zeros(101,101)
hm_hard = zeros(101,101)
for X=1:101
    t_eval=0.0
    for Y=1:101
        t_eval+=0.01
        hm_easy[Y,X] = sum([α_e[i,X]*Φ(t_eval, μ_e[i,X],σ_e[i,X],1) for i=1:1])
        hm_hard[Y,X] = sum([α_h[i,X]*Φ(t_eval, μ_h[i,X],σ_h[i,X],1) for i=1:3])
    end
end
p1=heatmap(hm_easy, title="easy", color=:pu_or)
p2=heatmap(hm_hard, title="hard", color=:pu_or)
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 35.5169,377.923 380.315,377.923 380.315,31.4961 35.5169,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="31" width="346" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   102.087,372.727 102.087,36.6925
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   170.364,372.727 170.364,36.6925
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   238.641,372.727 238.641,36.6925
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   306.917,372.727 306.917,36.6925
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   375.194,372.727 375.194,36.6925
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,311.039 375.143,311.039
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,242.439 375.143,242.439
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,173.84 375.143,173.84
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,105.24 375.143,105.24
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,36.641 375.143,36.641
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,377.923 380.315,377.923
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   102.087,377.923 102.087,372.727
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   170.364,377.923 170.364,372.727
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   238.641,377.923 238.641,372.727
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   306.917,377.923 306.917,372.727
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   375.194,377.923 375.194,372.727
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,377.923 35.5169,31.4961
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,311.039 40.6889,311.039
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,242.439 40.6889,242.439
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,173.84 40.6889,173.84
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,105.24 40.6889,105.24
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,36.641 40.6889,36.641
#   "/>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 102.087, 392.723)" x="102.087" y="392.723">20</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 170.364, 392.723)" x="170.364" y="392.723">40</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 238.641, 392.723)" x="238.641" y="392.723">60</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 306.917, 392.723)" x="306.917" y="392.723">80</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 375.194, 392.723)" x="375.194" y="392.723">100</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 315.539)" x="27.5169" y="315.539">20</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 246.939)" x="27.5169" y="246.939">40</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 178.34)" x="27.5169" y="178.34">60</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 109.74)" x="27.5169" y="109.74">80</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 41.141)" x="27.5169" y="41.141">100</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 207.916, 18)" x="207.916" y="18">easy</text>
# </g>
# <g clip-path="url(#clip2402)">
# <image width="345" height="346" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAVkAAAFaCAYAAAC0Zi51AAAgAElEQVR4nO2dV3djyZWlA94TBEHv
# XTKzSl6tlmmpW1JbremX+QvzV+a39LzMWr3mSdPTRi0vlVyVStWqTDKT3pOgAeH9PKTWPWcHeVHI
# rIyqNPt7OsgTAC4vLiJvbOxzIvA58489QwghbxCBQAAeB4MhL47FUl6cz8/DuM/+3We9+L//j29C
# 7s/Xil7c/un/lNf+eIdKCCGkH5xkCSHEIZxkCSHEIeFP+wAIIeSTBzXZQEA02XA45sWpVA7GTS3n
# JZ7LQi508RMvLhfPvJh3soQQ4hBOsoQQ4hDKBYSQNwSRCGwLVyh0t4VreDYD4+aXJrx4fCwOud6v
# 3/fidrPmxbyTJYQQh3CSJYQQh3CSJYQQh1CTJYS8EWgZNhDA+8tQKOrFicSQF+eXh2Hc9OKIF8dK
# DyHXON/04mA4IvHzHS4hhJBB4CRLCCEOoVxACHlDEL0gGMT7y0hE7FjpIZEIppfyMG5qTqSEYOEH
# kKsVT704lpbn8U6WEEIcwkmWEEIcwkmWEEIcQk2WEPKaYnfa0posTn1YSiu66/zyJIybGEt4ce/x
# +5DrqFLaxOiCvNezHDIhhJBng5MsIYQ4hHIBIeS1xGq0BVVe4XAUcsmkSASjK8rCtYhNuyPXf/Di
# 2tkm5IIhqfIKjH1G/v0ZjpkQQsgzwkmWEEIcQrmAEPIaEfCJjQkGpTF3NJqAXHpYJIKZpTEvnprB
# pt3Bs+97cV1VeBljTCwjVV7dsS/KcwY4akIIIc8JJ1lCCHEIJ1lCCHEINVlCyGtD/8bcYrGKxdKQ
# G5nPevH8smyWOJbD1+h9KFVeusLLGGOSY4te3Br+rBfzTpYQQhzCSZYQQhxCuYAQ8hrRrzF3zIuT
# Sdy7a+yeVHbNLEkcucImMJVTvY8XVo0FxkQiKFz3ZNxAx00IIeS54CRLCCEO4SRLCCEOoSZLCHnF
# ER22X2NuXUo7NJaF3OyilNJOTom9K3D4WxhXL555cTw7DrneuJTSnh6X5Tj6HzwhhJCPAydZQghx
# COUCQsgrjV
