# %% [markdown]
# <h1> Mixture Density Network </h1>
#
# This notebook is essentially a reproduction of the "Simple Inverse Problem" presented in
# <a href="http://publications.aston.ac.uk/373/1/NCRG_94_004.pdf">Mixture Density Networks (Bishop, 1994)</a>
#
# It shows the weakness a standard neural net has in predicting target data that has more than one mode. It motivates training the net to output a mixture model instead of a single conditioned average of the distribution.
#
# We create 2 datasets and compare 2 neural net architectures. In total, 4 neural nets are trained in this notebook.
#
# <h2> Two data sets that are really the same data:</h2>

# %%
datafunction(x) = x + 0.3*sin(2*π*x) + rand()*0.2-0.1
x = zeros(1,1001)
x .= collect(0:0.001:1)'
t = datafunction.(x)

using Plots; gr(size=(800,400), ylim=(0,1), xlim=(0,1), leg=false)
p1=scatter(x',t', title="easy")
p2=scatter(t',x', title="hard")
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip0100">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0101">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 32.2221,375.813 380.315,375.813 380.315,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0102">
#     <rect x="32" y="31" width="349" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,370.649 32.2221,36.6608
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.841,370.649 101.841,36.6608
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.459,370.649 171.459,36.6608
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.078,370.649 241.078,36.6608
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   310.696,370.649 310.696,36.6608
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   380.315,370.649 380.315,36.6608
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,375.813 375.094,375.813
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,306.95 375.094,306.95
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,238.086 375.094,238.086
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,169.223 375.094,169.223
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,100.36 375.094,100.36
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,31.4961 375.094,31.4961
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 380.315,375.813
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,370.649
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.841,375.813 101.841,370.649
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.459,375.813 171.459,370.649
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.078,375.813 241.078,370.649
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   310.696,375.813 310.696,370.649
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   380.315,375.813 380.315,370.649
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 37.4435,375.813
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,306.95 37.4435,306.95
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,238.086 37.4435,238.086
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,169.223 37.4435,169.223
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,100.36 37.4435,100.36
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,31.4961 37.4435,31.4961
#   "/>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 390.613)" x="32.2221" y="390.613">0.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.841, 390.613)" x="101.841" y="390.613">0.2</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.459, 390.613)" x="171.459" y="390.613">0.4</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 241.078, 390.613)" x="241.078" y="390.613">0.6</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 310.696, 390.613)" x="310.696" y="390.613">0.8</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 380.315, 390.613)" x="380.315" y="390.613">1.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 380.313)" x="24.2221" y="380.313">0.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 311.45)" x="24.2221" y="311.45">0.2</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 242.586)" x="24.2221" y="242.586">0.4</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 173.723)" x="24.2221" y="173.723">0.6</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 104.86)" x="24.2221" y="104.86">0.8</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 35.9961)" x="24.2221" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 206.269, 18)" x="206.269" y="18">easy</text>
# </g>
# <circle clip-path="url(#clip0102)" style="fi

# %% [markdown]
# <h2> Functions for implementing a Standard Neural Net and a Mixture Density Net</h2>

# %%
include("../toy_ffnet.jl")

function ∇MSE!(∇z, y,t)
    #get bprop started
    @. ∇z[2] = y[2]-t
end

Φ(t,μ,σ,c) = 1/(σ*(2*π)^(c/2)) * exp(-norm(t-μ)^2/(2*σ^2))

function ∇MD!(∇z, z,t, m,c)
    μ,σ,α = preds2params(z, m)
    p = α.*hcat([Φ.(t[1,:],μ[i,:],σ[i,:], c) for i=1:m]...)'
    pp = p./sum(p,1)
    
    #get bprop started
    ∇zμ = pp.*hcat([(μ[i,:].-t[1,:])./σ[i,:].^2 for i=1:m]...)'
    ∇zσ = -pp.*hcat([(t[1,:].-μ[i,:]).^2 ./ σ[i,:].^2 - c for i=1:m]...)'
    ∇zα = α.-pp
    ∇z[2] = vcat(∇zμ,∇zσ,∇zα)
end

function preds2params(z, m)
    μ = z[1:m,:]
    σ = exp.(z[m+1:2*m,:])
    α = nn.softmax(z[2*m+1:3*m,:])
    return μ,σ,α
end
# Out:
# preds2params (generic function with 1 method)

# %% [markdown]
# <h2> Standard Neural Net vs. Mixture Density Net</h2>

# %%
function trainFFN(x, t, Lw, bsz, Mepoch, α)
    W,b,z,y, ∇W,∇b,∇z,∇y = nn.preallocate(Lw,bsz)
    for epoch=1:Mepoch
        idx=randperm(size(x,2))
        for n=1:bsz:size(x,2)-bsz
            bidx=idx[n:n+bsz-1]
            xb=x[bidx]'
            nn.fprop!(xb, W,b,z,y)
            ∇MSE!(∇z, y,t[bidx]') # mean squared error output
            nn.bprop!(∇W,∇z,∇y, W,xb,y)
            nn.adjust!(W,b, ∇W,∇z, α)
        end
    end
    return W, b
end

function trainMDN(x, t, Lw, m,c, bsz, Mepoch, α)
    W,b,z,y, ∇W,∇b,∇z,∇y = nn.preallocate(Lw,bsz)
    for epoch=1:Mepoch
        idx=randperm(size(x,2))
        for n=1:bsz:size(x,2)-bsz
            bidx=idx[n:n+bsz-1]
            xb=x[bidx]'
            nn.fprop!(xb, W,b,z,y)
            ∇MD!(∇z, z[2], t[bidx]', m,c) #mixture model output
            nn.bprop!(∇W,∇z,∇y, W,xb,y)
            nn.adjust!(W,b, ∇W,∇z, α)
        end
    end
    return W, b
end
# Out:
# trainMDN (generic function with 1 method)

# %% [markdown]
# <h2>Train standard nets</h2>

# %%
Layerwidths=[1,20,1]
batchsize=16
learningrate=0.01
epochs=10000

We, be = trainFFN(x,t, Layerwidths, batchsize, epochs, learningrate) #easy data (x->t mapping)
Wh, bh = trainFFN(t,x, Layerwidths, batchsize, epochs, learningrate) #hard data (t->z mapping)

xeval=collect(0:0.01:1)'
preds_easy = nn.inference(xeval, We, be)
preds_hard = nn.inference(xeval, Wh, bh);

# %% [markdown]
# <h2> This is what they learn</h2>
# Its models the x->t mapping easily, but struggles with the t->x mapping
#
# The red dots are what the net predicts, given a certain input

# %%
p1=scatter(x',t', title="easy"); scatter!(p1, xeval', preds_easy')
p2=scatter(t',x', title="hard"); scatter!(p2, xeval', preds_hard')
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip0300">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0300)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0301">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0300)" points="
# 32.2221,377.923 380.315,377.923 380.315,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0302">
#     <rect x="32" y="31" width="349" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,372.727 32.2221,36.6925
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.841,372.727 101.841,36.6925
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.459,372.727 171.459,36.6925
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.078,372.727 241.078,36.6925
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   310.696,372.727 310.696,36.6925
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   380.315,372.727 380.315,36.6925
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,377.923 375.094,377.923
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,308.638 375.094,308.638
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,239.352 375.094,239.352
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,170.067 375.094,170.067
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,100.781 375.094,100.781
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,31.4961 375.094,31.4961
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 380.315,377.923
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,372.727
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.841,377.923 101.841,372.727
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.459,377.923 171.459,372.727
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.078,377.923 241.078,372.727
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   310.696,377.923 310.696,372.727
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   380.315,377.923 380.315,372.727
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 37.4435,377.923
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,308.638 37.4435,308.638
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,239.352 37.4435,239.352
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,170.067 37.4435,170.067
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,100.781 37.4435,100.781
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,31.4961 37.4435,31.4961
#   "/>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 392.723)" x="32.2221" y="392.723">0.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.841, 392.723)" x="101.841" y="392.723">0.2</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.459, 392.723)" x="171.459" y="392.723">0.4</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 241.078, 392.723)" x="241.078" y="392.723">0.6</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 310.696, 392.723)" x="310.696" y="392.723">0.8</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 380.315, 392.723)" x="380.315" y="392.723">1.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 382.423)" x="24.2221" y="382.423">0.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 313.138)" x="24.2221" y="313.138">0.2</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 243.852)" x="24.2221" y="243.852">0.4</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 174.567)" x="24.2221" y="174.567">0.6</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 105.281)" x="24.2221" y="105.281">0.8</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 35.9961)" x="24.2221" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 206.269, 18)" x="206.269" y="18">easy</text>
# </g>
# <circle clip-path="url(#clip0302

# %% [markdown]
# <h2> Train Mixture Density Nets</h2>

# %%
learningrate=0.0001
c=1 #dimensionality of output
m1=1 #nr of components
m2=3
Layerwidhts1=[1,20,(2+c)*m1]
Layerwidhts2=[1,20,(2+c)*m2]

We, be = trainMDN(x,t, Layerwidhts1, m1,1,batchsize, epochs, learningrate) #easy data (x->t mapping)
Wh, bh = trainMDN(t,x, Layerwidhts2, m2,1,batchsize, epochs, learningrate) #hard data (t->z mapping)

preds_easy = nn.inference(xeval, We, be); μe, σe, αe = preds2params(preds_easy, m1)
preds_hard = nn.inference(xeval, Wh, bh); μh, σh, αh = preds2params(preds_hard, m2);

# %% [markdown]
# <h2> This is what they learn</h2>
# It also models the x->t mapping easily. And does a better job with the t->x mapping
#
# The red dots are what the net predicts, given a certain input

# %%
p1=scatter(x',t', title="easy"); scatter!(p1, xeval', μe[findmax(αe,1)[2]]')
p2=scatter(t',x', title="hard"); scatter!(p2, xeval', μh[findmax(αh,1)[2]]')
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip0500">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0500)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0501">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0500)" points="
# 32.2221,377.923 380.315,377.923 380.315,31.4961 32.2221,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0502">
#     <rect x="32" y="31" width="349" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,372.727 32.2221,36.6925
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.841,372.727 101.841,36.6925
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.459,372.727 171.459,36.6925
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.078,372.727 241.078,36.6925
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   310.696,372.727 310.696,36.6925
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   380.315,372.727 380.315,36.6925
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,377.923 375.094,377.923
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,308.638 375.094,308.638
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,239.352 375.094,239.352
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,170.067 375.094,170.067
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,100.781 375.094,100.781
#   "/>
# <polyline clip-path="url(#clip0502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   37.4435,31.4961 375.094,31.4961
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 380.315,377.923
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,372.727
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.841,377.923 101.841,372.727
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.459,377.923 171.459,372.727
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.078,377.923 241.078,372.727
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   310.696,377.923 310.696,372.727
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   380.315,377.923 380.315,372.727
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 32.2221,31.4961
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,377.923 37.4435,377.923
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,308.638 37.4435,308.638
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,239.352 37.4435,239.352
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,170.067 37.4435,170.067
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,100.781 37.4435,100.781
#   "/>
# <polyline clip-path="url(#clip0500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,31.4961 37.4435,31.4961
#   "/>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.2221, 392.723)" x="32.2221" y="392.723">0.0</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.841, 392.723)" x="101.841" y="392.723">0.2</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.459, 392.723)" x="171.459" y="392.723">0.4</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 241.078, 392.723)" x="241.078" y="392.723">0.6</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 310.696, 392.723)" x="310.696" y="392.723">0.8</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 380.315, 392.723)" x="380.315" y="392.723">1.0</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 382.423)" x="24.2221" y="382.423">0.0</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 313.138)" x="24.2221" y="313.138">0.2</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 243.852)" x="24.2221" y="243.852">0.4</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 174.567)" x="24.2221" y="174.567">0.6</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 105.281)" x="24.2221" y="105.281">0.8</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 24.2221, 35.9961)" x="24.2221" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip0500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 206.269, 18)" x="206.269" y="18">easy</text>
# </g>
# <circle clip-path="url(#clip0502

# %% [markdown]
# <h2> Not only that</h2>
# We get means, variances and amplitudes of the mixture components. A heatmap visualizes more clearly what the mixture density net has learned. The plot above only shows the mean of the most probable kernel, but they all contribute to the posterior probabilities.
#
# With an input value of 0.5 the trained Mixture Density Net will say that the output is
# <li>about 0.2 with 25% probability,
# <li>about 0.5 with 50% probability,
# <li>about 0.8 with 25% probability.
#
# This is something a standard neural net cannot do.
#
# <h4>(see figure below) the strength of color corresponds to probability that the output (given an input) should lie in certain regions.</h4>

# %%
hm_easy = zeros(101,101)
hm_hard = zeros(101,101)
for X=1:101
    teval=0.0
    for Y=1:101
        teval+=0.01
        hm_easy[Y,X] = sum([αe[i,X]*Φ(teval, μe[i,X],σe[i,X],1) for i=1:1])
        hm_hard[Y,X] = sum([αh[i,X]*Φ(teval, μh[i,X],σh[i,X],1) for i=1:3])
    end
end
p1=heatmap(hm_easy, title="easy", color=:pu_or, xlim=(1,101), ylim=(1,101))
p2=heatmap(hm_hard, title="hard", color=:pu_or, xlim=(1,101), ylim=(1,101))
plot(p1,p2)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="400" viewBox="0 0 800 400">
# <defs>
#   <clipPath id="clip0700">
#     <rect x="0" y="0" width="800" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,400 800,400 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0701">
#     <rect x="160" y="0" width="561" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 35.5169,377.923 380.315,377.923 380.315,31.4961 35.5169,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0702">
#     <rect x="35" y="31" width="346" height="347"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   101.029,372.727 101.029,36.6925
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   169.988,372.727 169.988,36.6925
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   238.948,372.727 238.948,36.6925
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   307.907,372.727 307.907,36.6925
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   376.867,372.727 376.867,36.6925
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,312.102 375.143,312.102
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,242.817 375.143,242.817
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,173.531 375.143,173.531
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,104.246 375.143,104.246
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.6889,34.9603 375.143,34.9603
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,377.923 380.315,377.923
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.029,377.923 101.029,372.727
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   169.988,377.923 169.988,372.727
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   238.948,377.923 238.948,372.727
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   307.907,377.923 307.907,372.727
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   376.867,377.923 376.867,372.727
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,377.923 35.5169,31.4961
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,312.102 40.6889,312.102
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,242.817 40.6889,242.817
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,173.531 40.6889,173.531
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,104.246 40.6889,104.246
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,34.9603 40.6889,34.9603
#   "/>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 101.029, 392.723)" x="101.029" y="392.723">20</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 169.988, 392.723)" x="169.988" y="392.723">40</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 238.948, 392.723)" x="238.948" y="392.723">60</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 307.907, 392.723)" x="307.907" y="392.723">80</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 376.867, 392.723)" x="376.867" y="392.723">100</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 316.602)" x="27.5169" y="316.602">20</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 247.317)" x="27.5169" y="247.317">40</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 178.031)" x="27.5169" y="178.031">60</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 108.746)" x="27.5169" y="108.746">80</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 27.5169, 39.4603)" x="27.5169" y="39.4603">100</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 207.916, 18)" x="207.916" y="18">easy</text>
# </g>
# <g clip-path="url(#clip0702)">
# <image width="348" height="350" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAVwAAAFeCAYAAADJ3qcnAAAgAElEQVR4nO2dV5Nk2XWdT3rvqirL
# 267q7uoeAIQjQAL0IEGIoPQL9KwH/R096E2hFymCjJCCIRAAIRDEABAGQ2IIM5iZduW9N+l96WEY
# Z+91svKiuqfnTpv1Pe3sfSvtzdP3rFx778CnzTevDCGEEGNMAG6FQiEbx+NZyE1N3bfxX/7n34fc
# f/xPX7Zx43/8mY2Dz+U5EkII+a1wwSWEEJ/ggksIIT4R/qSfACGEvCgEAu5t0XBjsSTkhufzNl66
# Nwm5+PFPbLyx+tDGvMIlhBCf4IJLCCE+QUmBEEL+jUDAtYXJEplIoC1s/N6wjefvDEPuauW/2Pjo
# pGljXuESQohPcMElhBCf4IJLCCE+QQ2XEPKaI7ptIIDXoJFI3MaZ7AjkFu6KFWyyiNrv8bf+yca1
# etfGvMIlhBCf4IJLCCE+QUmBEPJao51gwWAIcrq6bGQhD7nFexM2ju7/EHL7mzs2DgXlAXiFSwgh
# PsEFlxBCfIILLiGE+AQ1XELIa422goVCEcglEjkbT7yBtrD5pSEb937zLcidnrVsnMvJffIKlxBC
# fIILLiGE+AQlBULIa4XbEUxLCrqyzBhjsnmREW7dwSbjY5mqjQ/fexNyzWbPxneW0jbmFS4hhPgE
# F1xCCPEJLriEEOIT1HAJIa8ZqOHqct5YLAW5kUUp5711bxxykb0f2Hhv5xRy0Yg8xugbfySP9QzP
# lhBCyDPABZcQQnyCkgIh5LWif1CkVIIlk9gRbPJ+0cbziwXItd7+to3PL9qQGx6K2jh655s25hUu
# IYT4BBdcQgjxCS64hBDiE9RwCSGvPFq39RoUmR0agtzi3Skbj8ROILf/wY9t3O5cQW5idkxyU1+z
# Ma9wCSHEJ7jgEkKIT1BSIIS8BqhBjkFc9uJx6eZVXELr1617Ig2Et78Nuf29iroPvHYd+9Sf2ni3
# JIMoeYVLCCE+wQWXEEJ8ggsuIYT4BDVcQsgriraCSRwO46BIXc47dW8UcnMLkqv
